# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu28303/AIT-LAB-tasks/blob/main/Task_7_Monkey_Banana_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = 4
board = [-1] * N

def safe(row, col):

  for i in range(row):

    if board[i] == col or abs(board[i] - col) == abs(i - row):
      return False
  return True

def solve(row):

  if row == N:
    return True


  for col in range(N):
    if safe(row, col):
      board[row] = col
      if solve(row + 1):
        return True
      board[row] = -1

  return False

if solve(0):
  for i in range(N):
    print(" ".join("Q" if board[i] == j else "_" for j in range(N)))
else:
  print("No solution found.")
# Out:
# _ Q _ _
# _ _ _ Q
# Q _ _ _
# _ _ Q _
