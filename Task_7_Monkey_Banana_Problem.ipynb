# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu28303/AIT-LAB-tasks/blob/main/Task_7_Monkey_Banana_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
monkey = "window"
box="window"
banana= False
print("monkey walks to box")
print("monkey pushes box under bananas")
box="under banana"
print("monkey climbs box")
print("monkey grasps bananas")
banana=True
print("Goal Achieved:",banana)
# Out:
# monkey walks to box
# monkey pushes box under bananas
# monkey climbs box
# monkey grasps bananas
# Goal Achieved: True
